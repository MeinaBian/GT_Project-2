# %%
import json
import requests
import pandas as pd
from sqlalchemy import create_engine

# %%
# DATA FROM USDA Food Surveys Research Group: Beltsville, MD

#  LINK = https://www.ars.usda.gov/northeast-area/beltsville-md-bhnrc/beltsville-human-nutrition-research-center/\
# food-surveys-research-group/docs/fndds-download-databases/

# FILE - 2017-2018 FNDDS At A Glance - FNDDS Ingredients 

csv_file = "Resources_usda/usda_17_18_Ingredients.csv"

# %%
# MAIN FOOD AVERSION
    # Gluten Free
    # Vegan
    # Vegetarian
    # Ketogenic (this data doesn't have Ketogenic)

ingredients_data_df = pd.read_csv(csv_file)
ingredients_data_df.head()
# Out:
#    Food code Main food description  WWEIA Category number  \
# 0   11000000           Milk, human                   9602
# 1   11100000             Milk, NFS                   1004
# 2   11100000             Milk, NFS                   1004
# 3   11100000             Milk, NFS                   1004
# 4   11100000             Milk, NFS                   1004
#
#   WWEIA Category description  Seq num  Ingredient code  \
# 0                 Human milk        1             1107
# 1          Milk, reduced fat        1             1077
# 2          Milk, reduced fat        2             1079
# 3          Milk, reduced fat        3             1082
# 4          Milk, reduced fat        4             1085
#
#                               Ingredient description  Ingredient weight (g)  \
# 0                         Milk, human, mature, fluid                  100.0
# 1   Milk, whole, 3.25% milkfat, with added vitamin D                   35.0
# 2  Milk, reduced fat, fluid, 2% milkfat, with add...                   37.0
# 3  Milk, lowfat, fluid, 1% milkfat, with added vi...                   17.0
# 4  Milk, nonfat, fluid, with added vitamin A and ...                   11.0
#
#    Retention code  Moisture change (%)
# 0               0                  0.0
# 1               0                  0.0
# 2               0                  0.0
# 3               0                  0.0
# 4               0                  0.0

# %%
ingredients_data_df.shape
# Out:
# (24896, 10)

# %%
# Remove rows missing data
ingredients_data_df = ingredients_data_df.dropna()

# Shape total after cleaning 
ingredients_data_df.shape
# Out:
# (24883, 10)

# %%
#checking columns and null values
ingredients_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24883 entries, 0 to 24895
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Food code                   24883 non-null  int64
#  1   Main food description       24883 non-null  object
#  2   WWEIA Category number       24883 non-null  int64
#  3   WWEIA Category description  24883 non-null  object
#  4   Seq num                     24883 non-null  int64
#  5   Ingredient code             24883 non-null  int64
#  6   Ingredient description      24883 non-null  object
#  7   Ingredient weight (g)       24883 non-null  float64
#  8   Retention code              24883 non-null  int64
#  9   Moisture change (%)         24883 non-null  float64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 2.1+ MB

# %%
ingredients_data_df["WWEIA Category description"].value_counts()
# Out:
# Meat mixed dishes                                   2162
# Fish                                                1569
# Soups                                               1127
# Cakes and pies                                      1062
# Pasta mixed dishes, excludes macaroni and cheese    1057
#                                                     ...
# Tap water                                              1
# Human milk                                             1
# Baby water                                             1
# Bottled water                                          1
# Grapes                                                 1
# Name: WWEIA Category description, Length: 167, dtype: int64

# %%
# Filtering columns 
reduced_data = ingredients_data_df.loc[:,['Food code', 'Main food description', 'WWEIA Category description', 'Ingredient description']]
reduced_data
# Out:
#        Food code                 Main food description  \
# 0       11000000                           Milk, human
# 1       11100000                             Milk, NFS
# 2       11100000                             Milk, NFS
# 3       11100000                             Milk, NFS
# 4       11100000                             Milk, NFS
# ...          ...                                   ...
# 24891   99998130     Sauce as ingredient in hamburgers
# 24892   99998210  Industrial oil as ingredient in food
# 24893   99998210  Industrial oil as ingredient in food
# 24894   99998210  Industrial oil as ingredient in food
# 24895   99998210  Industrial oil as ingredient in food
#
#             WWEIA Category description  \
# 0                           Human milk
# 1                    Milk, reduced fat
# 2                    Milk, reduced fat
# 3                    Milk, reduced fat
# 4                    Milk, reduced fat
# ...                                ...
# 24891  Not included in a food category
# 24892  Not included in a food category
# 24893  Not included in a food category
# 24894  Not included in a food category
# 24895  Not included in a food category
#
#                                   Ingredient description
# 0                             Milk, human, mature, fluid
# 1       Milk, whole, 3.25% milkfat, with added vitamin D
# 2      Milk, reduced fat, fluid, 2% milkfat, with add...
# 3      Milk, lowfat, fluid, 1% milkfat, with added vi...
# 4      Milk, nonfat, fluid, with added vitamin A and ...
# ...                                                  ...
# 24891                          Mustard, prepared, yellow
# 24892                Oil, industrial, canola, high oleic
# 24893           Oil, industrial, soy, fully hydrogenated
# 24894                Oil, industrial, soy, low linolenic
# 24895          Oil, industrial, soy, ultra low linolenic
#
# [24883 rows x 4 columns]

# %%
reduced_data
# Out:
#        Food code                 Main food description  \
# 0       11000000                           Milk, human
# 1       11100000                             Milk, NFS
# 2       11100000                             Milk, NFS
# 3       11100000                             Milk, NFS
# 4       11100000                             Milk, NFS
# ...          ...                                   ...
# 24891   99998130     Sauce as ingredient in hamburgers
# 24892   99998210  Industrial oil as ingredient in food
# 24893   99998210  Industrial oil as ingredient in food
# 24894   99998210  Industrial oil as ingredient in food
# 24895   99998210  Industrial oil as ingredient in food
#
#             WWEIA Category description  \
# 0                           Human milk
# 1                    Milk, reduced fat
# 2                    Milk, reduced fat
# 3                    Milk, reduced fat
# 4                    Milk, reduced fat
# ...                                ...
# 24891  Not included in a food category
# 24892  Not included in a food category
# 24893  Not included in a food category
# 24894  Not included in a food category
# 24895  Not included in a food category
#
#                                   Ingredient description
# 0                             Milk, human, mature, fluid
# 1       Milk, whole, 3.25% milkfat, with added vitamin D
# 2      Milk, reduced fat, fluid, 2% milkfat, with add...
# 3      Milk, lowfat, fluid, 1% milkfat, with added vi...
# 4      Milk, nonfat, fluid, with added vitamin A and ...
# ...                                                  ...
# 24891                          Mustard, prepared, yellow
# 24892                Oil, industrial, canola, high oleic
# 24893           Oil, industrial, soy, fully hydrogenated
# 24894                Oil, industrial, soy, low linolenic
# 24895          Oil, industrial, soy, ultra low linolenic
#
# [24883 rows x 4 columns]

# %%
df = reduced_data[reduced_data['Main food description'].str.contains( 'Vegetarian | gluten')]
df.head(100)
# Out:
#        Food code                              Main food description  \
# 11808   41811890       Vegetarian burger or patty, meatless, no bun
# 11816   41812400                                 Vegetarian pot pie
# 11817   41812400                                 Vegetarian pot pie
# 11818   41812400                                 Vegetarian pot pie
# 11819   41812400                                 Vegetarian pot pie
# ...          ...                                                ...
# 16955   58109130          Pizza, with meat, gluten-free thick crust
# 16956   58109140  Pizza, cheese and vegetables, gluten-free thin...
# 16957   58109140  Pizza, cheese and vegetables, gluten-free thin...
# 16958   58109140  Pizza, cheese and vegetables, gluten-free thin...
# 16959   58109140  Pizza, cheese and vegetables, gluten-free thin...
#
#       WWEIA Category description  \
# 11808     Processed soy products
# 11816   Bean, pea, legume dishes
# 11817   Bean, pea, legume dishes
# 11818   Bean, pea, legume dishes
# 11819   Bean, pea, legume dishes
# ...                          ...
# 16955                      Pizza
# 16956                      Pizza
# 16957                      Pizza
# 16958                      Pizza
# 16959                      Pizza
#
#                                   Ingredient description
# 11808           Veggie burgers or soyburgers, unprepared
# 11816  Wheat flour, white, all-purpose, enriched, ble...
# 11817        Shortening, vegetable, household, composite
# 11818  Margarine, regular, 80% fat, composite, stick,...
# 11819                    Beverages, water, tap, drinking
# ...                                                  ...
# 16955    Sausage, Italian, pork, mild, cooked, pan-fried
# 16956  Bread, gluten-free, white, made with rice flou...
# 16957   Sauce, pasta, spaghetti/marinara, ready-to-serve
# 16958                       Oil, olive, salad or cooking
# 16959        Cheese, mozzarella, low moisture, part-skim
#
# [100 rows x 4 columns]

# %%
searchfor = ['Veg','veg', 'gluten', 'Gluten']
df= reduced_data[reduced_data['Main food description'].str.contains('|'.join(searchfor))]
df
# Out:
#        Food code              Main food description  \
# 147     11440070        Vegetable dip, yogurt based
# 148     11440070        Vegetable dip, yogurt based
# 149     11440070        Vegetable dip, yogurt based
# 150     11440070        Vegetable dip, yogurt based
# 151     11440070        Vegetable dip, yogurt based
# ...          ...                                ...
# 24884   99997810  Vegetables as ingredient in curry
# 24885   99997810  Vegetables as ingredient in curry
# 24886   99997810  Vegetables as ingredient in curry
# 24887   99997810  Vegetables as ingredient in curry
# 24888   99997810  Vegetables as ingredient in curry
#
#             WWEIA Category description  \
# 147        Dips, gravies, other sauces
# 148        Dips, gravies, other sauces
# 149        Dips, gravies, other sauces
# 150        Dips, gravies, other sauces
# 151        Dips, gravies, other sauces
# ...                                ...
# 24884  Not included in a food category
# 24885  Not included in a food category
# 24886  Not included in a food category
# 24887  Not included in a food category
# 24888  Not included in a food category
#
#                                   Ingredient description
# 147                  Salad dressing, mayonnaise, regular
# 148                         Yogurt, Greek, plain, lowfat
# 149                                 Salt, table, iodized
# 150                        Onions, cooked, as ingredient
# 151                               Spices, parsley, dried
# ...                                                  ...
# 24884                     Carrots, cooked, as ingredient
# 24885                 Cauliflower, cooked, as ingredient
# 24886  Peas, green, frozen, cooked, boiled, drained, ...
# 24887                 Green beans, cooked, as ingredient
# 24888                Green pepper, cooked, as ingredient
#
# [3944 rows x 4 columns]

# %%
df['Food code'].nunique()
# Out:
# 646

# %%
df['Ingredient description']= df['Ingredient description'].str.replace(',',' ')
# Out:
# <ipython-input-13-c4b391a59473>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ingredient description']= df['Ingredient description'].str.replace(',',' ')

# %%
df
# Out:
#        Food code              Main food description  \
# 147     11440070        Vegetable dip, yogurt based
# 148     11440070        Vegetable dip, yogurt based
# 149     11440070        Vegetable dip, yogurt based
# 150     11440070        Vegetable dip, yogurt based
# 151     11440070        Vegetable dip, yogurt based
# ...          ...                                ...
# 24884   99997810  Vegetables as ingredient in curry
# 24885   99997810  Vegetables as ingredient in curry
# 24886   99997810  Vegetables as ingredient in curry
# 24887   99997810  Vegetables as ingredient in curry
# 24888   99997810  Vegetables as ingredient in curry
#
#             WWEIA Category description  \
# 147        Dips, gravies, other sauces
# 148        Dips, gravies, other sauces
# 149        Dips, gravies, other sauces
# 150        Dips, gravies, other sauces
# 151        Dips, gravies, other sauces
# ...                                ...
# 24884  Not included in a food category
# 24885  Not included in a food category
# 24886  Not included in a food category
# 24887  Not included in a food category
# 24888  Not included in a food category
#
#                                   Ingredient description
# 147                  Salad dressing  mayonnaise  regular
# 148                         Yogurt  Greek  plain  lowfat
# 149                                 Salt  table  iodized
# 150                        Onions  cooked  as ingredient
# 151                               Spices  parsley  dried
# ...                                                  ...
# 24884                     Carrots  cooked  as ingredient
# 24885                 Cauliflower  cooked  as ingredient
# 24886  Peas  green  frozen  cooked  boiled  drained  ...
# 24887                 Green beans  cooked  as ingredient
# 24888                Green pepper  cooked  as ingredient
#
# [3944 rows x 4 columns]

# %%
df.groupby('Food code')['Ingredient description'].apply(', '.join)
# Out:
# Food code
# 11440070    Salad dressing  mayonnaise  regular, Yogurt  G...
# 12350250    Salad dressing  mayonnaise  regular, Cream  so...
# 12350255    Salad dressing  mayonnaise  light, Sour cream ...
# 14202020    Cheese  cottage  lowfat  2% milkfat, Vegetable...
# 14410600    Cheese  cheddar (Includes foods for USDA's Foo...
#                                   ...
# 92550400    Beverages  Vegetable and fruit juice drink  re...
# 92550405    Beverages  Vegetable and fruit juice drink  re...
# 99997800    Spinach  cooked  as ingredient, Broccoli  cook...
# 99997804    Mushrooms  cooked  as ingredient, Onions  cook...
# 99997810    Potatoes  baked  flesh and skin  without salt,...
# Name: Ingredient description, Length: 646, dtype: object

# %%
df_merge_col = df.loc[~ df[['Food code', 'Main food description', 'WWEIA Category description']].duplicated(),['Food code', 'Main food description', 'WWEIA Category description']]
df_merge_col.set_index('Food code', inplace= True)
df_merge_col
# Out:
#                                        Main food description  \
# Food code
# 11440070                         Vegetable dip, yogurt based
# 12350250                              Vegetable dip, regular
# 12350255                                Vegetable dip, light
# 14202020                    Cheese, cottage, with vegetables
# 14410600                  Cheese, processed, with vegetables
# ...                                                      ...
# 92550400   Vegetable and fruit juice drink, with high vit...
# 92550405   Vegetable and fruit juice drink, with high vit...
# 99997800       Dark green vegetables as ingredient in omelet
# 99997804            Other vegetables as ingredient in omelet
# 99997810                   Vegetables as ingredient in curry
#
#                 WWEIA Category description
# Food code
# 11440070       Dips, gravies, other sauces
# 12350250       Dips, gravies, other sauces
# 12350255       Dips, gravies, other sauces
# 14202020            Cottage/ricotta cheese
# 14410600                            Cheese
# ...                                    ...
# 92550400                 Other diet drinks
# 92550405                      Fruit drinks
# 99997800   Not included in a food category
# 99997804   Not included in a food category
# 99997810   Not included in a food category
#
# [646 rows x 2 columns]

# %%
df_merge_col['Recipe']= df.groupby('Food code')['Ingredient description'].apply(', '.join)
df_merge_col
# Out:
#                                        Main food description  \
# Food code
# 11440070                         Vegetable dip, yogurt based
# 12350250                              Vegetable dip, regular
# 12350255                                Vegetable dip, light
# 14202020                    Cheese, cottage, with vegetables
# 14410600                  Cheese, processed, with vegetables
# ...                                                      ...
# 92550400   Vegetable and fruit juice drink, with high vit...
# 92550405   Vegetable and fruit juice drink, with high vit...
# 99997800       Dark green vegetables as ingredient in omelet
# 99997804            Other vegetables as ingredient in omelet
# 99997810                   Vegetables as ingredient in curry
#
#                 WWEIA Category description  \
# Food code
# 11440070       Dips, gravies, other sauces
# 12350250       Dips, gravies, other sauces
# 12350255       Dips, gravies, other sauces
# 14202020            Cottage/ricotta cheese
# 14410600                            Cheese
# ...                                    ...
# 92550400                 Other diet drinks
# 92550405                      Fruit drinks
# 99997800   Not included in a food category
# 99997804   Not included in a food category
# 99997810   Not included in a food category
#
#                                                       Recipe
# Food code
# 11440070   Salad dressing  mayonnaise  regular, Yogurt  G...
# 12350250   Salad dressing  mayonnaise  regular, Cream  so...
# 12350255   Salad dressing  mayonnaise  light, Sour cream ...
# 14202020   Cheese  cottage  lowfat  2% milkfat, Vegetable...
# 14410600   Cheese  cheddar (Includes foods for USDA's Foo...
# ...                                                      ...
# 92550400   Beverages  Vegetable and fruit juice drink  re...
# 92550405   Beverages  Vegetable and fruit juice drink  re...
# 99997800   Spinach  cooked  as ingredient, Broccoli  cook...
# 99997804   Mushrooms  cooked  as ingredient, Onions  cook...
# 99997810   Potatoes  baked  flesh and skin  without salt,...
#
# [646 rows x 3 columns]

# %%
df_merge_col
# Out:
#                                        Main food description  \
# Food code
# 11440070                         Vegetable dip, yogurt based
# 12350250                              Vegetable dip, regular
# 12350255                                Vegetable dip, light
# 14202020                    Cheese, cottage, with vegetables
# 14410600                  Cheese, processed, with vegetables
# ...                                                      ...
# 92550400   Vegetable and fruit juice drink, with high vit...
# 92550405   Vegetable and fruit juice drink, with high vit...
# 99997800       Dark green vegetables as ingredient in omelet
# 99997804            Other vegetables as ingredient in omelet
# 99997810                   Vegetables as ingredient in curry
#
#                 WWEIA Category description  \
# Food code
# 11440070       Dips, gravies, other sauces
# 12350250       Dips, gravies, other sauces
# 12350255       Dips, gravies, other sauces
# 14202020            Cottage/ricotta cheese
# 14410600                            Cheese
# ...                                    ...
# 92550400                 Other diet drinks
# 92550405                      Fruit drinks
# 99997800   Not included in a food category
# 99997804   Not included in a food category
# 99997810   Not included in a food category
#
#                                                       Recipe
# Food code
# 11440070   Salad dressing  mayonnaise  regular, Yogurt  G...
# 12350250   Salad dressing  mayonnaise  regular, Cream  so...
# 12350255   Salad dressing  mayonnaise  light, Sour cream ...
# 14202020   Cheese  cottage  lowfat  2% milkfat, Vegetable...
# 14410600   Cheese  cheddar (Includes foods for USDA's Foo...
# ...                                                      ...
# 92550400   Beverages  Vegetable and fruit juice drink  re...
# 92550405   Beverages  Vegetable and fruit juice drink  re...
# 99997800   Spinach  cooked  as ingredient, Broccoli  cook...
# 99997804   Mushrooms  cooked  as ingredient, Onions  cook...
# 99997810   Potatoes  baked  flesh and skin  without salt,...
#
# [646 rows x 3 columns]

# %%
df_merge_col = df_merge_col.reset_index()
df_merge_col
# Out:
#      Food code                              Main food description  \
# 0     11440070                        Vegetable dip, yogurt based
# 1     12350250                             Vegetable dip, regular
# 2     12350255                               Vegetable dip, light
# 3     14202020                   Cheese, cottage, with vegetables
# 4     14410600                 Cheese, processed, with vegetables
# ..         ...                                                ...
# 641   92550400  Vegetable and fruit juice drink, with high vit...
# 642   92550405  Vegetable and fruit juice drink, with high vit...
# 643   99997800      Dark green vegetables as ingredient in omelet
# 644   99997804           Other vegetables as ingredient in omelet
# 645   99997810                  Vegetables as ingredient in curry
#
#           WWEIA Category description  \
# 0        Dips, gravies, other sauces
# 1        Dips, gravies, other sauces
# 2        Dips, gravies, other sauces
# 3             Cottage/ricotta cheese
# 4                             Cheese
# ..                               ...
# 641                Other diet drinks
# 642                     Fruit drinks
# 643  Not included in a food category
# 644  Not included in a food category
# 645  Not included in a food category
#
#                                                 Recipe
# 0    Salad dressing  mayonnaise  regular, Yogurt  G...
# 1    Salad dressing  mayonnaise  regular, Cream  so...
# 2    Salad dressing  mayonnaise  light, Sour cream ...
# 3    Cheese  cottage  lowfat  2% milkfat, Vegetable...
# 4    Cheese  cheddar (Includes foods for USDA's Foo...
# ..                                                 ...
# 641  Beverages  Vegetable and fruit juice drink  re...
# 642  Beverages  Vegetable and fruit juice drink  re...
# 643  Spinach  cooked  as ingredient, Broccoli  cook...
# 644  Mushrooms  cooked  as ingredient, Onions  cook...
# 645  Potatoes  baked  flesh and skin  without salt,...
#
# [646 rows x 4 columns]

# %%
df_merge_col.to_csv('Resources_usda/merge_recipe.csv')

# %%
df.to_csv('Resources_usda/food_adversion.csv')

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\nadri\anaconda3\lib\site-packages (2.9.3)

# %%
connection_string = "postgres:postgres@localhost:5432/recipe_adversion"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# <ipython-input-30-d72bc75a6b62>:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['recipe_adversion']

# %%
df_merge_col.to_sql(name='recipe_adversion', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from recipe_adversion', con=engine).head()
# Out:
#   Food code               Main food description   WWEIA Category description  \
# 0  11440070         Vegetable dip, yogurt based  Dips, gravies, other sauces
# 1  12350250              Vegetable dip, regular  Dips, gravies, other sauces
# 2  12350255                Vegetable dip, light  Dips, gravies, other sauces
# 3  14202020    Cheese, cottage, with vegetables       Cottage/ricotta cheese
# 4  14410600  Cheese, processed, with vegetables                       Cheese
#
#                                               Recipe
# 0  Salad dressing  mayonnaise  regular, Yogurt  G...
# 1  Salad dressing  mayonnaise  regular, Cream  so...
# 2  Salad dressing  mayonnaise  light, Sour cream ...
# 3  Cheese  cottage  lowfat  2% milkfat, Vegetable...
# 4  Cheese  cheddar (Includes foods for USDA's Foo...

# %%
### The end ###
