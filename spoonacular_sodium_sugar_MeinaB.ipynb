# %%
## ETL Project 2 extra database for future use

# Extract(optional,pull extended receipe data including sodium and sugar columns from spoonacular API  
# transform to df by pandas
# Load in pdadmin with database spoon_sugar with postgres, and save tables with sodium and sugar col, repectively

# key variations from main table: 
##Based on research healthy meal should consider maxSugar and maxSodium, which is 
##less than 15 and between 200-500(here 100 per meal is setted), repectively. As followed:

# maxSugar=25 
# maxSodium=100
# number=15
# random=true

# %%
import requests
import json
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
from pprint import pprint

# %%
api_Key= "a21364208c9d43719315d65c34faa384" #or use a config file, here for convenience; 
url = "https://api.spoonacular.com/recipes/findByNutrients?maxSugar=25&maxSodium=100&number=15&random=true&apiKey=a21364208c9d43719315d65c34faa384"
query_url = f'{url}&apiKey={api_Key}'

# %%
response = requests.get(query_url).json()
pprint(response)
# Out:
# [{'calories': 62,
#   'carbs': '3g',
#   'fat': '5g',
#   'id': 632118,
#   'image': 'https://spoonacular.com/recipeImages/632118-312x231.jpg',
#   'imageType': 'jpg',
#   'protein': '1g',
#   'sodium': '41mg',
#   'sugar': '1g',
#   'title': 'Almond Cranberry Cookies'},
#  {'calories': 90,
#   'carbs': '21g',
#   'fat': '0g',
#   'id': 632363,
#   'image': 'https://spoonacular.com/recipeImages/632363-312x231.jpg',
#   'imageType': 'jpg',
#   'protein': '2g',
#   'sodium': '42mg',
#   'sugar': '17g',
#   'title': 'Angel Food Cake With Lemon Icing'},
#  {'calories': 524,
#   'carbs': '26g',
#   'fat': '39g',
#   'id': 632445,
#   'image': 'https://spoonacular.com/recipeImages/632445-312x231.jpg',
#   'imageType': 'jpg',
#   'protein': '7g',
#   'sodium': '73mg',
#   'sugar': '19g',
#   'title': 'Apothic Granita and Vanilla Panna Cotta'},
#  {'calories': 86,
#   'carbs': '2g',
#   'fat': '9g',
#   'id': 632790,
#   'image': 'https://spoonacular.com/recipeImages/632790-312x231.jpg',
#   'imageType': 'jpg',
#   'protein': '2g',
#   'sodium': '56mg',
#   'sugar': '1g',
#   'title': 'Arugula Walnut Pesto'},
#  {'calories': 104,
#   'carbs': '14g',
#   'fat': '5g',
#   'id': 637824,
#   'image': 'https://spoonacular.com/recipeImages/637824-312x231.jpg',
#   'imageType': 'jpg',
#   'protein': '1g',
#   'sodium': '73mg',
#   'sugar': '10g',
#   'title': 'Chewy Gingersnaps'},
#  {'calories': 104,
#   'carbs': '20g',
#   'fat': '3g',
#   'id': 639165,
#   'image': 'https://spoonacular.com/recipeImages/639165-312x231.jpg',
#   'imageType': 'jpg',
#   'protein': '2g',
#   'sodium': '8mg',
#   'sugar': '17g',
#   'title': 'Chocolate Pistachio Energy Bites'},
#  {'calories': 99,
#   'carbs': '17g',
#   'fat': '2g',
#   'id': 640708,
#   'image': 'https://spoonacular.com/recipeImages/640708-312x231.jpg',
#   'imageType': 'jpg',
#   'protein': '4g',
#   'sodium': '17mg',
#   'sugar': '2g',
#   'title': 'Creamy Squash Orzo'},
#  {'calories': 76,
#   'carbs': '12g',
#   'fat': '3g',
#   'id': 646484,
#   'image': 'https://spoonacular.com/recipeImages/646484-312x231.jpg',
#   'imageType': 'jpg',
#   'protein': '2g',
#   'sodium': '70mg',
#   'sugar': '3g',
#   'title': 'Healthy Hazelnut Cookies'},
#  {'calories': 162,
#   'carbs': '15g',
#   'fat': '11g',
#   'id': 646486,
#   'image': 'https://spoonacular.com/recipeImages/646486-312x231.jpg',
#   'imageType': 'jpg',
#   'protein': '1g',
#   'sodium': '78mg',
#   'sugar': '7g',
#   'title': 'Healthy Key Lime Pie Milkshake'},
#  {'calories': 73,
#   'carbs': '8g',
#   'fat': '4g',
#   'id': 650573,
#   'image': 'https://spoonacular.com/recipeImages/650573-312x231.jpg',
#   'imageType': 'jpg',
#   'protein': '1g',
#   'sodium': '95mg',
#   'sugar': '6g',
#   'title': 'Macaroon Cookies'},
#  {'calories': 407,
#   'carbs': '39g',
#   'fat': '26g',
#   'id': 650718,
#   'image': 'https://spoonacular.com/recipeImages/650718-312x231.jpg',
#   'imageType': 'jpg',
#   'protein': '7g',
#   'sodium': '74mg',
#   'sugar': '21g',
#   'title': 'Mandarin and Ruby Red Grapefruit Tiramisu'},
#  {'calories': 135,
#   'carbs': '13g',
#   'fat': '10g',
#   'id': 650789,
#   'image': 'https://spoonacular.com/recipeImages/650789-312x231.jpg',
#   'imageType': 'jpg',
#   'protein': '2g',
#   'sodium': '6mg',
#   'sugar': '5g',
#   'title': 'Mango Guacamole'},
#  {'calories': 103,
#   'carbs': '9g',
#   'fat': '7g',
#   'id': 659887,
#   'image': 'https://spoonacular.com/recipeImages/659887-312x231.jpg',
#   'imageType': 'jpg',
#   'protein': '2g',
#   'sodium': '37mg',
#   'sugar': '4g',
#   'title': 'Shortbread Lemon Cookies'},
#  {'calories': 46,
#   'carbs': '4g',
#   'fat': '3g',
#   'id': 663362,
#   'image': 'https://spoonacular.com/recipeImages/663362-312x231.jpg',
#   'imageType': 'jpg',
#   'protein': '1g',
#   'sodium': '23mg',
#   'sugar': '1g',
#   'title': 'Thick, Fudgy, One Bowl Brownies'},
#  {'calories': 10,
#   'carbs': '1g',
#   'fat': '1g',
#   'id': 1697601,
#   'image': 'https://spoonacular.com/recipeImages/1697601-312x231.jpg',
#   'imageType': 'jpg',
#   'protein': '0g',
#   'sodium': '8mg',
#   'sugar': '0g',
#   'title': 'Linguine with Clams - Linguine alle Vongole'}]

# %%
# request parameters= {
#  recipe_id:
#  recipe_title:
#  recipe_sodium:
#  recipe_sugar:

# above is additional to main table below
    #     'minCarbs': 1,
    #     'maxCarbs': 1,
    #     'minProtein': 1,
    #     'maxProtein': 1,
    #     'minCalories': 1,
    #     'maxCalories': 1,
    #     'minFat': 1,
    #     'maxFat': 1,
    #     'minSugar': 1,
    #     'maxSugar': 1,
    #     'number': 15,
    #     'random': 'true'
    #

# %%
counter = 0
recipe_id = []
recipe_title = []
recipe_sodium = []
recipe_sugar = []

# recipe_calories = []
# recipe_protein = []
# recipe_fat = []
# recipe_carbs = []

while counter < 500:
    query_url = f'{url}&apiKey={api_Key}'
    #response = requests.get(query_url).json()
    
    for i in range(len(response)):
        try:
            recipe_id.append(response[0]['id'])
        except KeyError:
            recipe_id.append('null')
        recipe_title.append(response[0]['title'])
        recipe_sodium.append(response[0]['sodium'])
        recipe_sugar.append(response[0]['sugar'])
#       recipe_calories.append(response[0]['calories'])
#       recipe_protein.append(response[0]['protein'])
#       recipe_fat.append(response[0]['fat'])
#       recipe_carbs.append(response[0]['carbs'])
    counter += 1

# %%
recipe_title
# Out:
# ['Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  'Almond Cranberry Cookies',
#  ...]

# %%
cols = list(zip(recipe_id, recipe_title, recipe_sodium, recipe_sugar))
df = pd.DataFrame(cols, columns=['Spoonacular Recipe ID', "Recipe", 'Recipe Sodium', "Recipe Sugar"])

# %%
df.head()
len(df)
df.columns
df.shape
# Out:
# (7500, 4)

# %%
df.to_csv("spoonacular_recipes_sugar.csv")

# %%
df = pd.read_csv ('spoonacular_recipes_sugar.csv')
print(df.nunique())
# Out:
# Unnamed: 0               7500
# Spoonacular Recipe ID       1
# Recipe                      1
# Recipe Sodium               1
# Recipe Sugar                1
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0  Spoonacular Recipe ID                    Recipe Recipe Sodium  \
# 0           0                 632118  Almond Cranberry Cookies          41mg
# 1           1                 632118  Almond Cranberry Cookies          41mg
# 2           2                 632118  Almond Cranberry Cookies          41mg
# 3           3                 632118  Almond Cranberry Cookies          41mg
# 4           4                 632118  Almond Cranberry Cookies          41mg
#
#   Recipe Sugar
# 0           1g
# 1           1g
# 2           1g
# 3           1g
# 4           1g

# %%
df = df.drop('Unnamed: 0', 1)
# Out:
# C:\Users\adele\anaconda3\envs\PythonData1\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
#df.head()

# %%
df.drop_duplicates()
df = df.rename(columns={'Spoonacular Recipe ID': 'spoonacular_recipe_id',
                        'Recipe': 'recipe',
                        'Recipe Sodium': 'recipe_sodium',
                        'Recipe Sugar': 'recipe_sugar',
#                        'Recipe Calories': 'recipe_calories',
#                        'Recipe Protein Content (grams)': 'recipe_protein_content_grams',
#                        'Recipe Fat Content (grams)': 'recipe_fat_content_grams',
#                        'Recipe Carbs Content (grams)': 'recipe_carbs_content_grams'
                       })
df.head()
dataTypeSeries = df.dtypes
dataTypeSeries
# Out:
# spoonacular_recipe_id     int64
# recipe                   object
# recipe_sodium            object
# recipe_sugar             object
# dtype: object

# %%
rds_connection_string = "postgres:postgres@localhost:5432/spoon_sugar"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# C:\Users\adele\anaconda3\envs\PythonData1\lib\site-packages\ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.
# ['spoon_sodium', 'spoon_sugar', 'spoonacular_recipes_sugar']

# %%
df.to_sql(name='spoonacular_sodium_sugar', con=engine, if_exists='append', index=False)
